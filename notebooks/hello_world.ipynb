# %% [markdown]
# # Hello, Data Science! 👋
# Quick check: imports, a tiny DataFrame, and a plot.

# %%
import sys; print(sys.version)
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.DataFrame({"x": range(1,6), "y": [2,4,3,5,7]})
df

# %%
df.plot(x="x", y="y", kind="line", marker="o", title="Tiny Test Plot"); plt.show()
